# %%
import glob, json
from datetime import datetime
import pandas as pd

# %% [markdown]
# ## Data load

# %%
all_pr_rows = []
pr_files = glob.glob("snapshot_*/**/*_pr_sharing*.json", recursive=True)
print(f"Found {len(pr_files)} snapshot PR files")

for file in pr_files:
    with open(file, "r") as f:
        data = json.load(f)
    # Each file has a "Sources" list
    if "Sources" in data:
        all_pr_rows.extend(data["Sources"])

print(f"Total PR records collected: {len(all_pr_rows)}")

df_all = pd.DataFrame(all_pr_rows)
print(df_all.shape)
df_all.head(3)
# Out:
# Found 9 snapshot PR files
# Total PR records collected: 1693
# (1693, 19)
#            Type                                                URL     Author  \
# 0  pull request            https://github.com/labdao/plex/pull/469  AdamGoyer
# 1  pull request            https://github.com/labdao/plex/pull/468  AdamGoyer
# 2  pull request  https://github.com/ActivityWatch/aw-webui/pull...  ErikBjare
#
#                  RepoName RepoLanguage  Number  \
# 0             labdao/plex           Go     469
# 1             labdao/plex           Go     468
# 2  ActivityWatch/aw-webui          Vue     455
#
#                                                Title  \
# 0                   add readme for openbabel to PLEX
# 1                         add readme  for Gnina #462
# 2  feat: improved categorization helper to includ...
#
#                                                 Body             CreatedAt  \
# 0  The Chatgpt Thread used to create this pull re...  2023-07-05T03:30:54Z
# 1  Link to the ChatGPT conversation used to creat...  2023-07-05T02:53:12Z
# 2  Came up with this while thinking about the bug...  2023-06-22T15:47:50Z
#
#   ClosedAt MergedAt             UpdatedAt State  Additions  Deletions  \
# 0     None     None  2023-07-05T03:30:59Z  OPEN         42          0
# 1     None     None  2023-07-05T04:20:31Z  OPEN         45          0
# 2     None     None  2023-06-22T15:52:32Z  OPEN         78         19
#
#    ChangedFiles  CommitsTotalCount  \
# 0             1                  1
# 1             1                  1
# 2             1                  1
#
#                                       ChatgptSharing  \
# 0  [{'URL': 'https://chat.openai.com/share/8bd338...
# 1  [{'URL': 'https://chat.openai.com/share/2c4b0d...
# 2  [{'URL': 'https://chat.openai.com/share/0c7588...
#
#                                     CommitSha
# 0  [a41124a8d7f8d54d68b777bd3781734188d35873]
# 1  [8199fe4135efd1500e3dc5c868048aa3cf118cb4]
# 2  [c93f546f2b9d2b97a6f340d4a1859f2aa80fd0a7]

# %% [markdown]
# ## Data Exploration
# Json files as a dictionary

# %%
df_python = df_all[df_all["RepoLanguage"] == "Python"]
print("Total Python PRs:", df_python.shape)
# Out:
# Total Python PRs: (232, 19)

# %%
bugfix_patterns = r"fix|bug|error|fail|typo|broken|patch|regression|resolve|correct"
df_bugfix = df_python[df_python["Title"].str.contains(bugfix_patterns, case=False, na=False)]
print("Total Python bug-fix PRs across snapshots:", df_bugfix.shape)
# Out:
# Total Python bug-fix PRs across snapshots: (32, 19)

# %%
from datetime import datetime

def parse_time(ts):
    if ts is None:
        return None
    return datetime.fromisoformat(ts.replace("Z", "+00:00"))

df_bugfix = df_bugfix.copy()
df_bugfix["CreatedAt_dt"] = df_bugfix["CreatedAt"].apply(parse_time)
df_bugfix["MergedAt_dt"] = df_bugfix["MergedAt"].apply(parse_time)

df_bugfix["TimeToIntegration_hours"] = (
    df_bugfix["MergedAt_dt"] - df_bugfix["CreatedAt_dt"]
).dt.total_seconds() / 3600

df_bugfix[["RepoName", "Title", "TimeToIntegration_hours", "Additions", "Deletions"]].head(32)
# Out:
#                              RepoName  \
# 24                   chitalian/gptask
# 170                  chitalian/gptask
# 302            comfyanonymous/ComfyUI
# 326                  chitalian/gptask
# 476            comfyanonymous/ComfyUI
# 491                  chitalian/gptask
# 555                 gradio-app/gradio
# 651            comfyanonymous/ComfyUI
# 664                  chitalian/gptask
# 733                 gradio-app/gradio
# 739                     cucumber/docs
# 744                 lfortran/lfortran
# 765   Theta-Limited/OpenAthenaAndroid
# 771       astahmer/openapi-zod-client
# 782   Theta-Limited/OpenAthenaAndroid
# 784   Theta-Limited/OpenAthenaAndroid
# 785   Theta-Limited/OpenAthenaAndroid
# 796            sashabaranov/go-openai
# 797                   unoplatform/uno
# 807      hoshotakamoto/banzukesurfing
# 829   metaphorsystems/metaphor-python
# 844            comfyanonymous/ComfyUI
# 858                  chitalian/gptask
# 1021  metaphorsystems/metaphor-python
# 1038           comfyanonymous/ComfyUI
# 1056                 chitalian/gptask
# 1229  metaphorsystems/metaphor-python
# 1247           comfyanonymous/ComfyUI
# 1268                 chitalian/gptask
# 1468  metaphorsystems/metaphor-python
# 1489           comfyanonymous/ComfyUI
# 1511                 chitalian/gptask
#
#                                                   Title  \
# 24                          Fix: recursive/glob support
# 170                         Fix: recursive/glob support
# 302   make ComfyUI installable via pip install with ...
# 326                         Fix: recursive/glob support
# 476   make ComfyUI installable via pip install with ...
# 491                         Fix: recursive/glob support
# 555                        Fixes audio streaming issues
# 651   make ComfyUI installable via pip install with ...
# 664                         Fix: recursive/glob support
# 733                        Fixes audio streaming issues
# 739   Improve the clarity and correctness of the doc...
# 744                           CMake: Fix LLVM detection
# 765   Fix #74: Correct for Lens Distortion for ray a...
# 771                fix(#147): improve handling of anyOf
# 782   Fix #74: Correct for Lens Distortion for ray a...
# 784   Fix #74: Correct for Lens Distortion for ray a...
# 785   Fix #74: Correct for Lens Distortion for ray a...
# 796   feat: allow more input types to functions, fix...
# 797   fix(skia): Fix element not clipped when render...
# 807     Addressing module not defined error in browser.
# 829   fixed incorrect description of type arg in met...
# 844   make ComfyUI installable via pip install with ...
# 858                         Fix: recursive/glob support
# 1021  fixed incorrect description of type arg in met...
# 1038  make ComfyUI installable via pip install with ...
# 1056                        Fix: recursive/glob support
# 1229  fixed incorrect description of type arg in met...
# 1247  make ComfyUI installable via pip install with ...
# 1268                        Fix: recursive/glob support
# 1468  fixed incorrect description of type arg in met...
# 1489  make ComfyUI installable via pip install with ...
# 1511                        Fix: recursive/glob support
#
#       TimeToIntegration_hours  Additions  Deletions
# 24                   1.715556         78         35
# 170                  1.715556         78         35
# 302                       NaN       3151        444
# 326                  1.715556         78         35
# 476                       NaN       3157        450
# 491                  1.715556         78         35
# 555                 18.679167         33         14
# 651                       NaN       3157        450
# 664                  1.715556         78         35
# 733                 18.679167         33         14
# 739                       NaN          1          1
# 744                       NaN          6          1
# 765                       NaN          0          0
# 771                 22.712500        246          7
# 782                       NaN          0          0
# 784                       NaN          0          0
# 785                       NaN          0          0
# 796                141.148333        180         21
# 797               1780.423333       2082        935
# 807                  0.346389        101         69
# 829                  0.039167          1          1
# 844                       NaN       3157        450
# 858                  1.715556         78         35
# 1021                 0.039167          1          1
# 1038                      NaN       3157        450
# 1056                 1.715556         78         35
# 1229                 0.039167          1          1
# 1247                      NaN       3157        450
# 1268                 1.715556         78         35
# 1468                 0.039167          1          1
# 1489                      NaN       3157        450
# 1511                 1.715556         78         35

# %%
columns_to_keep = [
    "RepoName", "Title", "URL", "CreatedAt", "MergedAt",
    "Additions", "Deletions", "ChangedFiles", "CommitsTotalCount",
    "TimeToIntegration_hours", "CommitSha", "ChatgptSharing"
]

df_bugfix_temp = df_bugfix[columns_to_keep].copy()

# Convert list columns to strings
for col in df_bugfix_temp.columns:
    if df_bugfix_temp[col].apply(lambda x: isinstance(x, list)).any():
        df_bugfix_temp[col] = df_bugfix_temp[col].astype(str)

df_bugfix_clean = df_bugfix_temp.drop_duplicates()

# %%
df_bugfix_clean.to_csv("bugfix_pr_dataset_all_snapshots.csv", index=False)
print("Saved dataset to bugfix_pr_dataset_all_snapshots.csv ")
# Out:
# Saved dataset to bugfix_pr_dataset_all_snapshots.csv

# %% [markdown]
# # Compute three traditional key metrics

# %%
# Extract Code Diff from GitHub (human fix)
import requests

def get_patch(repo_name, pr_number):
    """
    Download the raw patch (diff) of a PR from GitHub.
    e.g. repo_name = 'metaphorsystems/metaphor-python', pr_number = 14
    """
    url = f"https://github.com/{repo_name}/pull/{pr_number}.patch"
    r = requests.get(url)
    if r.status_code == 200:
        return r.text
    else:
        print(f"Failed to get patch for {repo_name} PR#{pr_number}")
        return None

# %%
# Parse Patch → Extract Before & After Snippets
import re

def extract_code_snippets_from_patch(patch_text):
    """
    A lightweight extractor:
    - Lines starting with '-' (excluding --- file headers) = before
    - Lines starting with '+' (excluding +++ headers) = after
    Returns: (before_code_str, after_code_str)
    """
    before_lines, after_lines = [], []
    for line in patch_text.splitlines():
        if line.startswith('---') or line.startswith('+++'):
            continue
        if line.startswith('-'):
            before_lines.append(line[1:])
        elif line.startswith('+'):
            after_lines.append(line[1:])
    return "\n".join(before_lines), "\n".join(after_lines)

# %%
# Compute CodeBLEU between Before & After
